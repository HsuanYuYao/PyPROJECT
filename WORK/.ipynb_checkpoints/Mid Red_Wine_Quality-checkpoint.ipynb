# %% [markdown]
# # Classify the quality of red wine based on physicochemical variables
# ## Discription
# Inputs include totally 11 variables: fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates and alcohol. Our goal is to predict whether the sample has a high quality(i.e. quality score>6) or not(i.e. quality score<=6). We first divide the samples into training datas and testing datas. Each time we choose any two of the input variables to perform SVC on training datas, predict the classes which the testing datas belong to and calculate the accuracy score of our model.
# ## Implementation

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("winequality-red.csv", sep = ";")

# %% [markdown]
# [dataset](https://archive.ics.uci.edu/ml/datasets/Wine+Quality)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# check for missing datas
df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
# check the data types
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# choose two of the 11 input variables
x = df.loc[:, ['fixed acidity','alcohol']].copy().values
x = x.reshape(1599, 2)

# %%
# divide the quality score into two class
y = df.loc[:, ['quality']].copy().values
y = y.ravel()
z = np.zeros(y.size)
z = z.ravel()
z[y>6] = 1

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import train_test_split

# %%
# divide the samples into training datas and testing datas
x_train, x_test, z_train, z_test = train_test_split(x, z, test_size = 0.3, random_state = 1)

# %%
# plot training datas
plt.scatter(x_train[:, 0], x_train[:, 1], c = z_train)

# %%
# training SVC model
clf = SVC()
clf.fit(x_train, z_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# predict the classes which the testing datas belong to
z_predict = clf.predict(x_test)

# %%
# plot the predicting result
plt.scatter(x_test[:, 0], x_test[:, 1], c = z_predict)

# %%
# plot the true value
plt.scatter(x_test[:, 0], x_test[:, 1], c = z_test)

# %%
from sklearn.metrics import accuracy_score

# %%
# calculate the accuracy score
accuracy_score(z_test, z_predict)
# Out:
# 0.8895833333333333

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(z_test, z_predict)
# Out:
# array([[410,  15],
#        [ 38,  17]], dtype=int64)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
X, Y = np.meshgrid(np.arange(4, 16, 0.5), np.arange(8, 15, 0.5))

# %%
X1 = X.ravel()
Y1 = Y.ravel()

# %%
Z1 = clf.predict(np.c_[X1, Y1])

# %%
plt.scatter(X1, Y1, c = Z1)

# %%
Z = Z1.reshape(X.shape)

# %%
plt.contourf(X, Y, Z, cmap = 'coolwarm', alpha = 0.8)
plt.scatter(x_train[:, 0], x_train[:, 1], c = z_train, cmap = 'coolwarm')

# %% [markdown]
# ## Conclusion
# After running all possible choices of the two variables, we found that the combination of fixed acidity and alcohol gives the highest accuracy score, so we show the result of the model with this two input variables above.

# %% [markdown]
# ## Citation
# P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.
