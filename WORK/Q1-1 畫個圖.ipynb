# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5,5,100)
y = np.exp(-1/x**2)

# %%
plt.plot(x,y)

# %%
plt.xkcd()
# Out:
# <matplotlib.pyplot.xkcd.<locals>.dummy_ctx at 0x6120c53a58>

# %%
plt.plot(x,y)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5,5,100)
y = np.exp(-1/x**2)

plt.xkcd()

plt.plot(x,y)
