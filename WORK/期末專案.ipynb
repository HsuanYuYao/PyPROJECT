# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("C:/Users/黃柏倫/Desktop/data/python project/大盤指數盤後數據.xlsx",header=0)

# %%
x_train=[]
y_train=[]
for i in range(len(df.index)-10):
    x_train.append(list(df.loc[i:i+9]['收盤價']))
    y_train.append(df.收盤價[i+10])

# %%
x_train=np.array(x_train)

# %%
x_train[1]
# Out:
# [122.93,
#  122.51,
#  121.94,
#  121.13,
#  122.04,
#  122.41,
#  122.38,
#  121.88,
#  123.03,
#  122.77]

# %%
y_train
# Out:
# [122.77,
#  122.87,
#  124.22,
#  124.59,
#  124.43,
#  125.77,
#  126.49,
#  126.89,
#  128.26,
#  127.9,
#  128.02,
#  128.96,
#  129.75,
#  129.89,
#  130.04,
#  131.4,
#  130.81,
#  132.25,
#  132.05,
#  131.55,
#  131.46,
#  130.34,
#  130.53,
#  130.04,
#  129.41,
#  128.7,
#  127.69,
#  128.71,
#  129.39,
#  129.01,
#  128.63,
#  128.48,
#  127.97,
#  127.92,
#  128.55,
#  127.82,
#  127.94,
#  128.99,
#  128.25,
#  126.69,
#  125.71,
#  124.99,
#  124.8,
#  125.25,
#  124.85,
#  124.17,
#  124.3,
#  123.99,
#  123.27,
#  123.44,
#  122.65,
#  122.76,
#  122.87,
#  122.44,
#  121.16,
#  120.61,
#  118.01,
#  117.78,
#  118.48,
#  119.87,
#  120.04,
#  119.09,
#  118.96,
#  118.72,
#  118.43,
#  118.27,
#  118.58,
#  118.06,
#  118.16,
#  118.57,
#  118.12,
#  117.48,
#  116.95,
#  116.76,
#  116.48,
#  117.02,
#  117.06,
#  117.08,
#  118.2,
#  117.94,
#  117.84,
#  118.03,
#  118.11,
#  118.15,
#  117.56,
#  118.11,
#  118.35,
#  118.34,
#  118.16,
#  119.04,
#  119.19,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(500, input_dim=10,activation='relu'))
model.add(Dense(1, activation='relu'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 500)               5500
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 501
# ...
# Total params: 6,001
# Trainable params: 6,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mean_squared_error",metrics=['acc'])#,validation)

# %%
from sklearn.model_selection import train_test_split

# %%
X = x.reshape(len(x), 1)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 9487)
plt.scatter(x_train, y_train)

# %%
model.fit(x_train, y_train,epochs=5)
# Out:
# Epoch 1/5
# 13144/13144 [==============================] - 1s 50us/step - loss: 18307.3491 - acc: 3.8040e-04
# Epoch 2/5
# 13144/13144 [==============================] - 0s 30us/step - loss: 18484.2737 - acc: 2.2824e-04
# Epoch 3/5
# 13144/13144 [==============================] - 0s 31us/step - loss: 13564.6745 - acc: 1.5216e-04
# Epoch 4/5
# 13144/13144 [==============================] - 0s 31us/step - loss: 12044.6572 - acc: 3.0432e-04
# Epoch 5/5
# 13144/13144 [==============================] - 0s 31us/step - loss: 12253.1856 - acc: 7.6080e-05

# %%
model.evaluate(x_test, y_test)
