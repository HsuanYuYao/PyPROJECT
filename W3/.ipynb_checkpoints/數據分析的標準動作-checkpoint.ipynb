# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#     %matplotlib inline : 把matplotlib的圖直接呈現在jupyter notebook的網頁上
#     %pylab inline : 除此之外還偷偷讀進很多套件，包含numpy, matplotlib...

# %%
plt.plot([3, -4, 1, 5, -2, 7, 3, -5, 6])

# %%
plt.plot(np.random.randn(100))

# %% [markdown]
# 用tab鍵可以自動補完剩下的指令

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
